# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/aniyant/shipment-pricing-prediction-dataset/main/SCMS_Delivery_History_Dataset.csv")

# %%
from six.moves import urllib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#pd.pandas.set_option("display.max_columns",None)
# %matplotlib inline

# %%
from urllib.request import urlretrieve

# %%
df
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
urlretrieve("https://raw.githubusercontent.com/aniyant/shipment-pricing-prediction-dataset/main/SCMS_Delivery_History_Dataset.csv","C:/Users/aniyant/Desktop/shipmet")
# Out:
# ('C:/Users/aniyant/Desktop/shipmet', <http.client.HTTPMessage at 0x30ec449130>)

# %%
df.to_csv("C:/Users/aniyant/Desktop/shipment.csv")

# %%
df
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
len(df.columns)
# Out:
# 33

# %%
df["Freight Cost (USD)"].isna().sum()
# Out:
# 4126

# %%
df["Freight Cost (USD)"].dropna(axis=)

# %%
df["Freight Cost (USD)"] = df["Freight Cost (USD)"].apply(lambda x: pd.to_numeric(x,errors="coerce")).dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# ID                                  0
# Project Code                        0
# PQ #                                0
# PO / SO #                           0
# ASN/DN #                            0
# Country                             0
# Managed By                          0
# Fulfill Via                         0
# Vendor INCO Term                    0
# Shipment Mode                     360
# PQ First Sent to Client Date        0
# PO Sent to Vendor Date              0
# Scheduled Delivery Date             0
# Delivered to Client Date            0
# Delivery Recorded Date              0
# Product Group                       0
# Sub Classification                  0
# Vendor                              0
# Item Description                    0
# Molecule/Test Type                  0
# Brand                               0
# Dosage                           1736
# Dosage Form                         0
# Unit of Measure (Per Pack)          0
# Line Item Quantity                  0
# ...

# %%
df["Freight Cost (USD)"] = pd.cut(
                df["Freight Cost (USD)"],
                bins=[0.0, 1.5, 3.0, 4.5, 6.0, np.inf],
                labels=[1,2,3,4,5]
            )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-41a91262f13c> in <module>
# ----> 1 df["Freight Cost (USD)"] = pd.cut(
#       2                 df["Freight Cost (USD)"],
#       3                 bins=[0.0, 1.5, 3.0, 4.5, 6.0, np.inf],
#       4                 labels=[1,2,3,4,5]
#       5             )
#
# c:\Users\aniyant\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290             raise ValueError("bins must increase monotonically.")
#     291
# --> 292     fac, bins = _bins_to_cuts(
#     293         x,
#     294         bins,
#
# c:\Users\aniyant\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     425
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_train,x_test,y_test = train_test_split(df test_size=0.21, random_state=42,)

for train_index,test_index in split.split(df, df["Freight Cost (USD)"]):
    strat_train_set = df.loc[train_index].drop(["Freight Cost (USD)"],axis=1)
    strat_test_set = df.loc[test_index].drop(["Freight Cost (USD)"],axis=1)
# Out:
#   File "<ipython-input-87-52b200036708>", line 1
#     x_train,y_train,x_test,y_test = train_test_split(df test_size=0.21, random_state=42,)
#                                                         ^
# SyntaxError: invalid syntax

# %%
x_train,x_test,y_train,y_test = train_test_split(df.drop(["Freight Cost (USD)"],axis=1),df["Freight Cost (USD)"], test_size=0.21, random_state=42,)

# %%
y_train
# Out:
# 940     Freight Included in Commodity Cost
# 9436               See DN-2073 (ID#:82362)
# 4755    Freight Included in Commodity Cost
# 3529                              20258.29
# 538                    Invoiced Separately
#                        ...
# 5734             See ASN-31765 (ID#:41640)
# 5191                                5187.9
# 5390                   Invoiced Separately
# 860     Freight Included in Commodity Cost
# 7270               See DN-2858 (ID#:82511)
# Name: Freight Cost (USD), Length: 8155, dtype: object

# %%
x_train
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 940    9658   116-ZA-T01  Pre-PQ Process   SCMS-19800   ASN-1665
# 9436  85729   106-HT-T30        FPQ-6484     SO-37760    DN-2073
# 4755  50031   116-ZA-T30       FPQ-12522  SCMS-199280  ASN-24433
# 3529  28181   161-ZA-T30        FPQ-7175  SCMS-103880  ASN-11458
# 538    5295   102-NG-T01  Pre-PQ Process     SCMS-229    ASN-155
# ...     ...          ...             ...          ...        ...
# 5734  67225   105-SS-T30       FPQ-15569  SCMS-272150  ASN-31765
# 5191  57997   109-TZ-T30       FPQ-11881  SCMS-182820  ASN-19790
# 5390  61852   105-GY-T30       FPQ-16480  SCMS-293570  ASN-33568
# 860    9024   116-ZA-T01  Pre-PQ Process   SCMS-40840   ASN-3779
# 7270  83081   900-SS-T30       FPQ-10517     SO-43070    DN-2858
#
#            Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 940   South Africa   PMO - US  Direct Drop              DDP         Truck
# ...

# %%
x_test
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 6584  82275   110-ZM-T30        FPQ-4035     SO-34340    DN-1515
# 1692  11520   117-ET-T01  Pre-PQ Process      SO-1512     DN-517
# 2692  13064   116-ZA-T30       FPQ-14942  SCMS-259075  ASN-32122
# 7702  83607   151-NG-T30        FPQ-9432     SO-42803    DN-2769
# 321    3039   111-MZ-T01  Pre-PQ Process   SCMS-18060   ASN-1651
# ...     ...          ...             ...          ...        ...
# 9010  85195   200-ZW-T30        FPQ-6483     SO-38902    DN-2290
# 6947  82691   110-ZM-T30       FPQ-13221     SO-47204    DN-3833
# 37      361   125-HT-T01  Pre-PQ Process   SCMS-14080   ASN-1318
# 9645  85953   111-MZ-T30       FPQ-10211     SO-42862    DN-3086
# 4818  51267   133-NG-T30       FPQ-10765  SCMS-162440  ASN-18601
#
#            Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 6584        Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\aniyant\Visual-Code-Projects\ml-project\Shipment-Pricing-Prediction\shipment\artifact\2022-07-18-14-34-46\data_ingestion\ingested_dir\ingested_test_dir\SCMS_Delivery_History_Dataset.csv")

# %%
df
# Out:
#      Project Code            PQ #    PO / SO #   ASN/DN #             Country  \
# 0      109-TZ-T30        FPQ-8303     SO-40502    DN-2593            Tanzania
# 1      102-BI-T30       FPQ-13627     SO-47670    DN-3712             Burundi
# 2      108-VN-T30        FPQ-9576  SCMS-145320  ASN-16055             Vietnam
# 3      114-UG-T30       FPQ-10558  SCMS-160440  ASN-16895              Uganda
# 4      104-CI-T01  Pre-PQ Process      SO-1105     DN-393       Côte d'Ivoire
# ...           ...             ...          ...        ...                 ...
# 1235   104-CI-T30       FPQ-12150  SCMS-191920  ASN-21574       Côte d'Ivoire
# 1236   200-DO-T30        FPQ-6616     SO-38030    DN-2066  Dominican Republic
# 1237   111-MZ-T30       FPQ-13123     SO-47090    DN-3826          Mozambique
# 1238   104-CI-T30        FPQ-8790     SO-41202    DN-2752       Côte d'Ivoire
# 1239   104-CI-T30       FPQ-13628     SO-47910    DN-4092       Côte d'Ivoire
#
# ...

# %%
test = pd.read_csv(r"C:\Users\aniyant\Visual-Code-Projects\ml-project\Shipment-Pricing-Prediction\shipment\artifact\2022-07-18-14-34-46\data_ingestion\ingested_dir\ingested_train_dir\SCMS_Delivery_History_Dataset.csv")

# %%
test
# Out:
#      Project Code            PQ #    PO / SO #   ASN/DN #        Country  \
# 0      113-ZW-T30        FPQ-7521  SCMS-108020  ASN-13966       Zimbabwe
# 1      161-ZA-T30        FPQ-6708   SCMS-93580   ASN-9951   South Africa
# 2      110-ZM-T30        FPQ-8476     SO-40955    DN-2624         Zambia
# 3      104-CI-T30       FPQ-11254     SO-44151    DN-3247  Côte d'Ivoire
# 4      109-TZ-T30        FPQ-3782   SCMS-47730   ASN-4489       Tanzania
# ...           ...             ...          ...        ...            ...
# 4953   103-KE-T30       FPQ-10018  SCMS-149610  ASN-15668          Kenya
# 4954   151-NG-T30        FPQ-8364     SO-40665    DN-2561        Nigeria
# 4955   114-UG-T30       FPQ-10780     SO-43470    DN-2971         Uganda
# 4956   151-NG-T30        FPQ-5688     SO-36952    DN-2044        Nigeria
# 4957   100-CI-T01  Pre-PQ Process       SO-373      DN-30  Côte d'Ivoire
#
#      Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# ...
